# %%
import pandas as pd
import datetime as dt
import numpy as np
import sqlite3

# %%
dbpath = "./movies.db"
con = sqlite3.connect(dbpath)
movie_list = pd.read_sql("SELECT * FROM features", con, index_col=None)
movie_list
# Out:
#          id                  title        open nation                producer  \
# 0     00000                   국제시장  2014-12-17     한국     (주)제이케이필름,씨제이이앤엠(주)
# 1     00001                  테이큰 3  2015-01-01     미국                    None
# 2     00002              마다가스카의 펭귄  2014-12-31     미국                    None
# 3     00003        님아, 그 강을 건너지 마오  2014-11-27     한국                   아거스필름
# 4     00004                   언브로큰  2015-01-07     미국                    None
# 5     00005                    패딩턴  2015-01-07     영국                    None
# 6     00006                   기술자들  2014-12-24     한국           (주)트리니티엔터테인먼트
# 7     00007                    워킹걸  2015-01-07     한국           (주)홍필름,(주)수필름
# 8     00008           호빗: 다섯 군대 전투  2014-12-17     미국                    None
# 9     00009                타임 패러독스  2015-01-07     호주                    None
# 10    00010                  인터스텔라  2014-11-06     미국                    None
# ...

# %%
from tqdm import tqdm_notebook

for i in tqdm_notebook(movie_list.index):
    if movie_list['open'][i]== None:
        continue
    movie_list['open'][i]="".join(movie_list['open'][i].split('-'))
movie_list.head(5)
# Out:
# A Jupyter Widget
# C:\Users\gudrb\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       id            title      open nation             producer  \
# 0  00000             국제시장  20141217     한국  (주)제이케이필름,씨제이이앤엠(주)
# 1  00001            테이큰 3  20150101     미국                 None
# 2  00002        마다가스카의 펭귄  20141231     미국                 None
# 3  00003  님아, 그 강을 건너지 마오  20141127     한국                아거스필름
# 4  00004             언브로큰  20150107     미국                 None
#
#            distributor     grade              genre         director  \
# 0            씨제이이앤엠(주)  12세이상관람가                드라마              윤제균
# 1         이십세기폭스코리아(주)  15세이상관람가          액션,범죄,스릴러         올리비에 메가턴
# 2            씨제이이앤엠(주)     전체관람가  애니메이션,코미디,어드벤처,가족  에릭 다넬,사이몬 J.스미스
# ...

# %%
movie_list2 = movie_list.copy()

# %%
nation = movie_list['nation']
nation = list(nation.drop_duplicates())
nation
# Out:
# ['한국', '영미권', '일본', '중국', '기타']

# %%
for i in tqdm_notebook(movie_list.index):
    if movie_list['nation'][i]== "한국":
        movie_list['nation'][i] = "한국"
    elif movie_list['nation'][i]== "미국" or movie_list['nation'][i]=="영국" or\
        movie_list['nation'][i]== "호주" or movie_list['nation'][i]=="캐나다" or\
        movie_list['nation'][i]== "뉴질랜드":
        movie_list['nation'][i] = "영미권"
    elif movie_list['nation'][i]== "러시아" or movie_list['nation'][i]=="벨기에" or\
        movie_list['nation'][i]== "독일" or movie_list['nation'][i]=="프랑스" or\
        movie_list['nation'][i]== "우크라이나" or movie_list['nation'][i]=="폴란드" or\
        movie_list['nation'][i]== "이탈리아" or movie_list['nation'][i]=="아일랜드" or\
        movie_list['nation'][i]== "핀란드" or movie_list['nation'][i]=="스페인" or\
        movie_list['nation'][i]== "스웨덴" or movie_list['nation'][i]=="헝가리" or\
        movie_list['nation'][i]== "체코" or movie_list['nation'][i]=="노르웨이" or\
        movie_list['nation'][i]== "오스트리아" or movie_list['nation'][i]=="덴마크" or\
        movie_list['nation'][i]== "그리스" or movie_list['nation'][i]=="터키":
        movie_list['nation'][i] = "영미권"
    elif movie_list['nation'][i]== "중국" or movie_list['nation'][i]=="대만" or\
        movie_list['nation'][i]== "홍콩" :
        movie_list['nation'][i] = "중국"
    elif movie_list['nation'][i]== "일본":
        movie_list['nation'][i] = "일본"
    else:
        movie_list['nation'][i] = "기타"
# Out:
# A Jupyter Widget
# C:\Users\gudrb\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\gudrb\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\gudrb\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# ...

# %%
movie_list.head(50)
# Out:
#        id                        title      open nation  \
# 0   00000                         국제시장  20141217     한국
# 1   00001                        테이큰 3  20150101    영미권
# 2   00002                    마다가스카의 펭귄  20141231    영미권
# 3   00003              님아, 그 강을 건너지 마오  20141127     한국
# 4   00004                         언브로큰  20150107    영미권
# 5   00005                          패딩턴  20150107    영미권
# 6   00006                         기술자들  20141224     한국
# 7   00007                          워킹걸  20150107     한국
# 8   00008                 호빗: 다섯 군대 전투  20141217    영미권
# 9   00009                      타임 패러독스  20150107    영미권
# 10  00010                        인터스텔라  20141106    영미권
# 11  00011                      아메리칸 셰프  20150107    영미권
# 12  00012                개를 훔치는 완벽한 방법  20141231     한국
# 13  00013            눈의 여왕 2: 트롤의 마법거울  20141224    영미권
# 14  00014                          상의원  20141224     한국
# 15  00015                    내일을 위한 시간  20150101    영미권
# ...

# %%
distributor = movie_list['distributor']
distributor = list(distributor.drop_duplicates())
distributor
# Out:
# ['씨제이이앤엠(주)',
#  '이십세기폭스코리아(주)',
#  'CGV아트하우스',
#  '유니버설픽쳐스인터내셔널 코리아(유)',
#  '롯데쇼핑㈜롯데엔터테인먼트',
#  '메가박스중앙(주)플러스엠',
#  '워너브러더스 코리아(주)',
#  '(유)조이앤시네마',
#  '(주)영화사 진진',
#  '(주)리틀빅픽쳐스',
#  '씨네그루(주)다우기술',
#  '(주)쇼박스',
#  '그린나래미디어(주)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)엣나인필름',
#  '(주)마인스 엔터테인먼트',
#  '주식회사 단유필름',
#  '(주)나이너스엔터테인먼트',
#  'THE 픽쳐스',
#  '월트디즈니컴퍼니코리아(주)',
#  '(주)프레인글로벌',
#  '이십세기폭스필름코퍼레이션',
#  '(주)팝엔터테인먼트',
#  '판씨네마(주)',
#  '(주)영화사 빅',
#  '(주)박수엔터테인먼트',
#  '(주)티캐스트콘텐츠허브',
#  '(주)드림팩트엔터테인먼트',
#  '에이원엔터테인먼트',
#  '와이드 릴리즈(주)',
#  '(주)인스터피씨엠',
#  '(주)이수C&E',
#  '오드',
#  None,
#  '(주)영화사오원',
#  '시네마 뉴원',
#  '(주)스톰픽쳐스코리아',
#  '(주)피터팬픽쳐스',
#  '오퍼스픽쳐스',
#  '예지림엔터테인먼트',
#  '(주)대명문화공장',
#  '프리비젼엔터테인먼트',
#  '(주)씨타마운틴픽쳐스',
#  '(주)제이앤씨미디어그룹',
#  '(주)엔케이컨텐츠',
#  '(주)디스테이션',
#  '(주)와우픽쳐스',
#  '(주)브리즈픽처스',
#  '찬란',
#  '(주)블룸즈베리리소시스리미티드',
#  '(주)영화사 안다미로',
#  '㈜인디스토리',
#  '(주)누리픽쳐스',
#  '(주)시네마서비스',
#  '(주)씨네월드',
#  '(주)머스트씨무비릴리징컴퍼니',
#  '(주)티캐스트',
#  '씨네힐',
#  '주식회사 씨네룩스',
#  '주식회사 해리슨앤컴퍼니',
# ...

# %%
for i in tqdm_notebook(movie_list.index):
    if movie_list['distributor'][i]== None:
        continue
    movie_list['distributor'][i]=movie_list['distributor'][i].split(',')[0]
# Out:
# A Jupyter Widget
# C:\Users\gudrb\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
grade = movie_list['grade']
grade = list(grade.drop_duplicates())
grade
# Out:
# ['12세이상관람가', '15세이상관람가', '전체관람가', '청소년관람불가', None, '18세관람가']

# %%
for i in tqdm_notebook(movie_list.index):
    if movie_list['grade'][i]== None:
        continue
    elif movie_list['grade'][i]== "12세이상관람가" or movie_list['grade'][i]== "12세이상관람가,중학생이상관람가" or \
        movie_list['grade'][i]== "중학생이상관람가" or movie_list['grade'][i]== "12세이상관람가,국민학생관람불가,15세이상관람가" or\
        movie_list['grade'][i]== "12세관람가" or movie_list['grade'][i]== "12세이상관람가,12세관람가" or \
        movie_list['grade'][i]== "12세이상관람가,연소자관람가":
        movie_list['grade'][i] = "12세이상관람가"
    elif movie_list['grade'][i]== "15세이상관람가" or movie_list['grade'][i]== "15세관람가,15세이상관람가" or \
        movie_list['grade'][i]== "고등학생이상관람가,15세이상관람가" or movie_list['grade'][i]== "15세 미만인 자는 관람할 수 없는 등급 ,15세이상관람가" or\
        movie_list['grade'][i]== "15세관람가" or movie_list['grade'][i]== "연소자관람불가,15세이상관람가" or\
        movie_list['grade'][i]== "15세이상관람가,중학생이상관람가" or movie_list['grade'][i]== "12세이상관람가,15세이상관람가":
        movie_list['grade'][i] = "15세이상관람가"
    elif movie_list['grade'][i]== "전체관람가" or movie_list['grade'][i]=="12세이상관람가,연소자관람가,전체관람가" or\
        movie_list['grade'][i]== "연소자관람가,전체관람가" or movie_list['grade'][i]== "모든 관람객이 관람할 수 있는 등급,전체관람가":
        movie_list['grade'][i] = "전체관람가"
    elif movie_list['grade'][i]== "청소년관람불가" or movie_list['grade'][i]=="국민학생관람불가,청소년관람불가" or\
        movie_list['grade'][i]== "미성년자관람불가" or movie_list['grade'][i]=="연소자관람불가,청소년관람불가":
        movie_list['grade'][i] = "청소년관람불가"
    else:
        movie_list['grade'][i] = "18세관람가"
# Out:
# A Jupyter Widget
# C:\Users\gudrb\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\gudrb\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\gudrb\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# ...

# %%
genre = movie_list['genre']
genre = list(genre.drop_duplicates())
genre
# Out:
# ['드라마',
#  '액션',
#  '애니메이션',
#  '다큐멘터리',
#  '코미디',
#  '범죄',
#  '어드벤처',
#  'SF',
#  '사극',
#  '멜로/로맨스',
#  '가족',
#  '공연',
#  '스릴러',
#  '공포(호러)',
#  '미스터리',
#  '판타지',
#  '기타',
#  '전쟁',
#  None,
#  '뮤지컬']

# %%
for i in tqdm_notebook(movie_list.index):
    if movie_list['genre'][i]== None:
        continue
    movie_list['genre'][i]=movie_list['genre'][i].split(',')[0]
# Out:
# A Jupyter Widget
# C:\Users\gudrb\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
movie_list.to_excel("movie_list.xlsx")

# %%
import math
score = {}
for i in tqdm_notebook(movie_list.index):
    if math.isnan(movie_list['score'][i]):
        score[movie_list['title'][i]]=None
# Out:
# ...
# {'빽 투 더 퓨쳐': None,
#  '센과 치히로의 행방불명': None,
#  '리바이어던': None,
#  '부에나 비스타 소셜 클럽': None,
#  '미션': None,
#  '불의 전차': None,
#  '모스트 바이어런트': None,
#  '조제, 호랑이 그리고 물고기들': None,
#  '챔피언': None,
#  '원스 어폰 어 타임 인 아메리카': None,
#  '시간을 달리는 소녀': None,
#  '마담 보바리': None,
#  '원스': None,
#  '말할 수 없는 비밀': None,
#  '러브레터': None,
#  '지금, 만나러 갑니다': None,
#  '쇼생크 탈출': None,
#  '걸어도 걸어도': None,
#  '스파이': None,
#  '원더풀 라이프': None,
#  '미드나잇 인 파리': None,
#  '피아니스트': None,
#  '그 시절, 우리가 좋아했던 소녀': None,
#  '타이타닉': None,
#  '포켓몬 레인저와 바다의 왕자 마나피': None,
#  '디올 앤 아이': None,
#  '노인을 위한 나라는 없다': None,
#  '데자뷰': None,
#  '바다의 노래: 벤과 셀키요정의 비밀': None,
#  '사운드 오브 뮤직': None,
#  '러브 액츄얼리': None,
#  '라이프': None,
#  '이터널 선샤인': None,
#  '빽 투더 퓨쳐 2': None,
#  '렛 미 인': None,
#  '쏘아올린 불꽃, 밑에서 볼까? 옆에서 볼까?': None,
#  '포레스트 검프': None,
#  '냉정과 열정사이': None,
#  '아이 엠 러브': None,
#  '무간도': None,
#  '초속5센티미터': None,
#  '인생은 아름다워': None,
#  '최악의 이웃과 사랑에 빠지는 방법': None,
#  '비포 선라이즈': None,
#  '두 번째 스물': None,
# ...

# %%
from tqdm import trange
#df = pd.read_excel('C:/Users/SEC/Desktop/2013-2017데이터(이상치처리전).xlsx')
df1 = pd.read_excel('C:/Users/SEC/Desktop/2018원본데이터.xlsx')

keys = list(score.keys())
for i in trange(0, len(score)):
    for j in df1.index:
        if keys[i]==df1['영화명'][j]:
            score[keys[i]]=df1['평점'][j]
            
#score
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 274/274 [00:00<00:00, 299.08it/s]

# %%
for i in tqdm_notebook(movie_list.index):
    for j in range(0, len(score)):
        if movie_list['title'][i] == keys[j]:
            movie_list['score'][i]=score[keys[j]]
# Out:
# ...
# C:\Users\SEC\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#          id                  title        open nation                producer  \
# 0     00000                   국제시장  2014-12-17     한국     (주)제이케이필름,씨제이이앤엠(주)
# 1     00001                  테이큰 3  2015-01-01     미국                    None
# 2     00002              마다가스카의 펭귄  2014-12-31     미국                    None
# 3     00003        님아, 그 강을 건너지 마오  2014-11-27     한국                   아거스필름
# 4     00004                   언브로큰  2015-01-07     미국                    None
# 5     00005                    패딩턴  2015-01-07     영국                    None
# 6     00006                   기술자들  2014-12-24     한국           (주)트리니티엔터테인먼트
# ...

# %%
a = pd.read_excel('C:/Users/SEC/Desktop/평점.xlsx')


for i in tqdm_notebook(movie_list.index):
    if math.isnan(movie_list['score'][i]):
        for j in a.index:
            if movie_list['title'][i]== a['영화명'][j]:
                movie_list['score'][i] = a['평점'][j]
# Out:
# ...
# C:\Users\SEC\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i in tqdm_notebook(movie_list.index):
    if movie_list['open'][i]== None:
        continue
    movie_list['open'][i]="".join(movie_list['open'][i].split('-'))
# Out:
# ...
# C:\Users\SEC\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
movie_list
# Out:
#          id                  title      open nation                producer  \
# 0     00000                   국제시장  20141217     한국     (주)제이케이필름,씨제이이앤엠(주)
# 1     00001                  테이큰 3  20150101     미국                    None
# 2     00002              마다가스카의 펭귄  20141231     미국                    None
# 3     00003        님아, 그 강을 건너지 마오  20141127     한국                   아거스필름
# 4     00004                   언브로큰  20150107     미국                    None
# 5     00005                    패딩턴  20150107     영국                    None
# 6     00006                   기술자들  20141224     한국           (주)트리니티엔터테인먼트
# 7     00007                    워킹걸  20150107     한국           (주)홍필름,(주)수필름
# 8     00008           호빗: 다섯 군대 전투  20141217     미국                    None
# 9     00009                타임 패러독스  20150107     호주                    None
# 10    00010                  인터스텔라  20141106     미국                    None
# ...
